# %% [markdown]
# > 🗑️ **작성 안내 — 완성 후 이 셀을 삭제하세요**
# >
# > # 📘 이 템플릿 사용법
# >
# > **셀 종류**
# >
# > | 표시 | 의미 | 제출 시 |
# > |---|---|---|
# > | 🗑️ 로 시작하는 셀 | 작성 안내 | **삭제** |
# > | 빈 코드 셀 | 직접 코딩 | 채워서 제출 |
# > | 빈칸·빈 표가 있는 셀 | 직접 작성 | 채워서 제출 |
# > | "실행만 하세요" 셀 | 완성된 셀 | 그대로 제출 |
# >
# > **제출 전 반드시**
# > 1. 🗑️ 셀을 **모두 삭제** (편집기에서 `🗑️` 로 검색하면 빠릅니다)
# > 2. `Kernel > Restart & Run All` 실행 → 출력이 살아있는 상태로 저장
# > 3. 남은 빈칸 `( )` 이 없는지 확인
# >
# > **작성 규칙 4가지**
# > 1. 모든 코드 셀 아래에 **해석 한 줄**을 남긴다. 해석 없는 출력은 의미 없다.
# > 2. 없는 배경·이해관계자를 지어내지 않는다. "공개 데이터로 기법을 연습했다"가 정직하다.
# > 3. 종속변수는 **연속형 1개**. 분류 문제에는 이 템플릿을 쓰지 않는다.
# > 4. 안내 셀을 지우고 나면 그대로 하나의 보고서가 되도록 작성한다.

# %% [markdown]
# # (프로젝트 제목)
#
# **작성자:** &nbsp;&nbsp;|&nbsp;&nbsp; **작성일:** &nbsp;&nbsp;|&nbsp;&nbsp; **GitHub:**

# %% [markdown]
# ---
# # #0. 요약 (Executive Summary)

# %% [markdown]
# > 🗑️ **작성 안내 — 완성 후 이 셀을 삭제하세요**
# >
# > ⚠️ **이 섹션은 모든 분석을 끝낸 뒤 마지막에 작성합니다.**
# > 채용 담당자는 이 화면만 보고 넘어갈 수 있습니다.
# >
# > - 제목은 "○○로 △△를 설명할 수 있는가" 형태의 **질문**으로 답니다.
# > - 요약은 `무엇을 · 어떤 변수로 · 최종 모형 · 설명력 · 무엇을 알아냈는가` 5요소를 3~5줄에 담습니다.
# >
# > 👇 아래 두 셀을 채우세요.

# %% [markdown]
# - **데이터:** (Kaggle 데이터셋명 / URL)
# - **규모:** (관측치 수) × (변수 수)
# - **문제 유형:** 예측(회귀)
#
# **요약**
#
# >

# %% [markdown]
# ### 핵심 결과
#
# | 항목 | 내용 |
# |---|---|
# | 최종 모형 | |
# | 설명력 | 조정 R² = &nbsp;&nbsp; / RMSE = |
# | 유의 변수 | |
# | 가정 검토 | 선형성 ( ) / 정규성 ( ) / 등분산성 ( ) / 독립성 ( ) |
# | 이번에 연습한 기법 | |

# %% [markdown]
# > 🗑️ **작성 안내 — 완성 후 이 셀을 삭제하세요**
# >
# > 아래 셀에 **결론을 한 장으로 보여주는 그래프**를 그리세요.
# > 추천: 실제값 vs 예측값 산점도 / 표준화계수 막대그래프

# %% [markdown]
# ---
# # #1. 분석 개요

# %% [markdown]
# > 🗑️ **작성 안내 — 완성 후 이 셀을 삭제하세요**
# >
# > 📌 **화면 한 장을 넘기지 마세요.** 여기서 오래 붙잡지 말고 #2로 넘어갑니다.
# >
# > - 분석 질문은 2~3개. #8에서 이 번호에 하나씩 답하게 됩니다.
# > - "연습할 기법"은 #9 회고와 짝을 이룹니다. 예: *"변수선택법과 잔차진단을 연습한다"*
# >
# > 👇 아래 셀을 채우세요.

# %% [markdown]
# **분석 주제**
#
# >
#
# **분석 질문**
#
# - **Q1.**
# - **Q2.**
#
# **종속변수:** `변수명` (연속형) → 예측(회귀) 문제
#
# **이번 노트북에서 연습할 기법**
#
# >

# %% [markdown]
# ### 1-1. 분석 환경 설정

# %% [markdown]
# > 분석에 필요한 개별 함수 **import**

# %% [markdown]
# ---
# # #2. 데이터 소개

# %% [markdown]
# > 🗑️ **작성 안내 — 완성 후 이 셀을 삭제하세요**
# >
# > **2-1. 데이터 로딩**
# >
# > 아래 두 셀에서 데이터를 불러오고 첫인상을 확인하세요.
# >
# > - 파일 경로는 **상대경로**로 씁니다. 절대경로를 쓰면 다른 사람이 실행할 수 없습니다.
# > - 첫인상 확인: 앞부분 몇 행 · 행과 열의 크기 · 변수별 자료형

# %% [markdown]
# > 🗑️ **작성 안내 — 완성 후 이 셀을 삭제하세요**
# >
# > **2-2 ~ 2-5** — 아래 네 셀을 채웁니다.
# >
# > - **변수 정의서**는 필수입니다. 이 표 하나로 "데이터를 이해하고 시작했는가"가 판별됩니다.
# > - **초기 가설**은 거창한 이론이 아니라 **상식 수준의 예상**이면 됩니다.
# >   목적은 EDA 결과와 대조할 기준선을 미리 적어두는 것입니다.
# >   예: *"H1. BMI가 높을수록 의료비가 높을 것이다"*

# %% [markdown]
# ### 2-2. 출처와 분석 단위
#
# - **출처:**
# - **수집 기간:**
# - **분석 단위:** 1행 = ( )

# %% [markdown]
# ### 2-3. 변수 정의서
#
# | 변수명 | 의미 | 역할 | 척도 | 단위 |
# |---|---|---|---|---|
# | | | 종속변수 | 연속형 | |
# | | | 독립변수 | | |
# | | | 독립변수 | | |
# | | | 독립변수 | | |

# %% [markdown]
# ### 2-4. 초기 가설
#
# - **H1.**
# - **H2.**
# - **H3.**

# %% [markdown]
# ### 2-5. 데이터의 한계
#
# >

# %% [markdown]
# ---
# # #3. 품질 점검 및 기본 전처리

# %% [markdown]
# > 🗑️ **작성 안내 — 완성 후 이 셀을 삭제하세요**
# >
# > ⚠️ **이 장에서는 삭제만 수행합니다.** 결측치·이상치의 **대체는 #5**에서 합니다.
# > 이유: 전처리 기준이 분석 설계보다 앞서면 판단 근거가 사라집니다.
# >
# > 이 원칙을 지켰다는 사실 자체가 실력 증명이므로, 해석 셀에 한 줄로 명시해두면 좋습니다.

# %% [markdown]
# ### 3-1. 데이터 구조 점검

# %% [markdown]
# > 🗑️ **작성 안내 — 완성 후 이 셀을 삭제하세요**
# >
# > 아래 세 코드 셀에서 차례로 수행하세요.
# >
# > 1. 자료형 점검 및 필요 시 변환
# > 2. 중복값 점검 및 처리
# > 3. 불필요한 열 삭제 (ID처럼 분석에 쓸 수 없는 열)

# %% [markdown]
# **해석**
#
# >

# %% [markdown]
# ### 3-2. 데이터 품질 점검

# %% [markdown]
# > 🗑️ **작성 안내 — 완성 후 이 셀을 삭제하세요**
# >
# > 아래 다섯 코드 셀에서 차례로 수행하세요. 이 단계에서는 **삭제만** 합니다.
# >
# > 1. 결측치 현황 — 변수별 결측 **개수와 비율**을 표로
# > 2. 결측치 삭제
# > 3. 이상치 현황 — 박스플롯으로 시각화
# > 4. 이상치 탐지 — **IQR 기준** (1사분위수·3사분위수로부터 IQR의 1.5배를 벗어나는 값)
# > 5. 처리 전후 관측치 수 변화 출력

# %% [markdown]
# **해석** — 결측치 ( )건, 이상치 ( )건 삭제. 관측치 ( ) → ( ).
#
# 삭제 기준과 그렇게 정한 이유
#
# >

# %% [markdown]
# ### 3-3. 기술통계량

# %% [markdown]
# > 🗑️ **작성 안내 — 완성 후 이 셀을 삭제하세요**
# >
# > 기술통계량과 함께 **왜도·첨도**를 확인하세요.
# >
# > 해석은 **숫자 나열이 아니라 판단**을 적습니다.
# > 예: *"charges는 왜도가 커서 우측 꼬리가 길다 → #5에서 로그변환 대상"*

# %% [markdown]
# **해석**
#
# - **중심수준:**
# - **퍼짐 정도:**
# - **비대칭 신호:** (왜도가 큰 변수 → 로그변환 후보)

# %% [markdown]
# ### 3-4. 이 장의 결론
#
# - 분석용 데이터 최종 크기:
# - 삭제 내역과 근거:

# %% [markdown]
# ---
# # #4. 탐색적 데이터 분석 (EDA)
#
# ### 4-1. 분포 확인

# %% [markdown]
# > 🗑️ **작성 안내 — 완성 후 이 셀을 삭제하세요**
# >
# > **종속변수**의 분포를 히스토그램과 밀도곡선으로 확인하세요.
# > 우측 꼬리가 길면 #5에서 **로그변환**을 검토합니다.

# %% [markdown]
# **해석**
#
# >

# %% [markdown]
# > 🗑️ **작성 안내 — 완성 후 이 셀을 삭제하세요**
# >
# > **독립변수**들의 분포를 확인하세요. 여러 변수를 한 번에 그리면 비교가 쉽습니다.

# %% [markdown]
# **해석**
#
# >

# %% [markdown]
# ### 4-2. 변수 간 관계

# %% [markdown]
# > 🗑️ **작성 안내 — 완성 후 이 셀을 삭제하세요**
# >
# > ⭐ **선형회귀를 써도 되는지 판단하는 단계입니다.**
# >
# > 아래 두 코드 셀에서 수행하세요.
# >
# > 1. 상관계수 행렬과 히트맵
# > 2. 종속변수 ↔ 주요 독립변수의 **산점도** (회귀선 포함)
# >
# > **판정 기준**
# > - 산점도가 **직선 추세** → 선형회귀 적용 가능
# > - **곡선·계단** 형태 → 변수 변환 또는 다항항 검토 (#6-4)

# %% [markdown]
# **해석**
#
# - 종속변수와 상관이 높은 변수:
# - **산점도의 형태 — 선형회귀 적용이 타당한가:**
# - 곡선 형태로 보이는 변수 (변환 검토 대상):

# %% [markdown]
# > 🗑️ **작성 안내 — 완성 후 이 셀을 삭제하세요**
# >
# > 명목형 독립변수가 있다면 집단 간 종속변수 평균 차이를 검정하세요.
# >
# > - 2집단 → **T-Test**
# > - 3집단 이상 → **ANOVA**
# >
# > 명목형 변수가 없으면 이 코드 셀을 삭제하고, 아래 표에 "해당 없음"이라고 적으세요.

# %% [markdown]
# **검정 결과**
#
# | 변수 | 검정 | 통계량 | p-value | 판단 | 관련 가설 |
# |---|---|---|---|---|---|
# | | | | | | |

# %% [markdown]
# > 🗑️ **작성 안내 — 완성 후 이 셀을 삭제하세요**
# >
# > 독립변수끼리 상관이 높은 쌍(0.8 이상)을 찾아 출력하세요.
# > #5에서 **VIF**로 다시 확인하게 됩니다.

# %% [markdown]
# **해석**
#
# >

# %% [markdown]
# ### 4-3. 모델링 설계 근거

# %% [markdown]
# > 🗑️ **작성 안내 — 완성 후 이 셀을 삭제하세요**
# >
# > 📌 **이 노트북의 분기점입니다.** #2-4의 초기 가설을 EDA 결과로 확정·수정하고,
# > 어떤 변수를 왜 투입할지 결정합니다.
# >
# > 평가지표는 **조정 R²(설명 중심)** 과 **RMSE(예측 중심)** 중 우선순위를 정하고
# > 그 이유를 한 줄로 적습니다. #7에서 이 기준으로 최종 모형을 고르게 됩니다.

# %% [markdown]
# **가설 확정**
#
# | 가설 | EDA 근거 | 확정 / 수정 / 기각 |
# |---|---|---|
# | H1 | | |
# | H2 | | |
# | H3 | | |
#
# **투입 변수 선정**
#
# - 투입할 변수:
# - 제외할 변수와 이유:
#
# **변수 변환 필요성**
#
# - 로그변환 대상:
# - 다항항·구간화 검토:
#
# **평가지표 우선순위와 이유**
#
# >

# %% [markdown]
# ---
# # #5. 모델링용 전처리

# %% [markdown]
# > 🗑️ **작성 안내 — 완성 후 이 셀을 삭제하세요**
# >
# > 항목마다 **처리 기준 · 이유 · 전후 비교**를 남기세요.
# >
# > 아래 세 코드 셀에서 차례로 수행합니다.
# >
# > 1. 파생변수 생성 (필요한 경우) — 생성 후 기술통계량 재확인
# > 2. **로그 변환** — 왜도가 큰 변수 / 종속변수
# >    ⚠️ 값에 0이 포함될 수 있다면 그대로 로그를 취할 수 없습니다. 대응 방법을 찾아보세요.
# > 3. 변환 **전후 분포 비교** — 두 그래프를 나란히 배치

# %% [markdown]
# **해석** — 변환 후 왜도 ( ) → ( ). 정규성이 개선되었는가?
#
# >

# %% [markdown]
# > 🗑️ **작성 안내 — 완성 후 이 셀을 삭제하세요**
# >
# > 아래 세 코드 셀에서 차례로 수행합니다.
# >
# > 4. **결측치·이상치 대체** — 평균/중앙값/회귀대체 중 선택.
# >    **어떤 기준을 왜 골랐는지**가 핵심입니다.
# > 5. **더미변수 인코딩**
# >    ⚠️ 범주가 k개면 더미는 **k-1개**만 만듭니다. 전부 만들면 다중공선성이 발생합니다
# >    (더미변수 함정, dummy trap).
# > 6. **다중공선성 확인 (VIF)** — 변수별 VIF 값을 표로 출력
# >    판정: **VIF ≥ 10** 이면 다중공선성 의심 → 변수 제거 또는 통합

# %% [markdown]
# **해석** — VIF ≥ 10 인 변수: ( )
#
# 처리 방법과 이유
#
# >

# %% [markdown]
# ### 5-N. 전처리 요약
#
# | 처리 항목 | 대상 변수 | 적용 기준 | 이유 | 전후 변화 |
# |---|---|---|---|---|
# | | | | | |
# | | | | | |

# %% [markdown]
# > 🗑️ **작성 안내 — 완성 후 이 셀을 삭제하세요**
# >
# > **데이터 분할 여부는 스스로 판단합니다.**
# >
# > - 예측 성능(RMSE)까지 평가한다 → 여기서 **학습/검증 분할** 후 위 전처리를 학습 데이터 기준으로 수행
# > - 설명(계수 해석)이 목적이다 → 전체 데이터로 적합해도 무방
# >
# > 정답이 있는 항목이 아닙니다. **선택한 쪽과 이유를 한 줄로 밝히는 것**이 채점 대상입니다.
# > 분할하지 않기로 했다면 아래 코드 셀은 삭제하세요.

# %% [markdown]
# ### 5-N+1. 데이터 분할 여부
#
# 선택한 방식과 이유
#
# >

# %% [markdown]
# ---
# # #6. 모형 구축
#
# ### 6-1. 단순회귀 (베이스라인)

# %% [markdown]
# > 🗑️ **작성 안내 — 완성 후 이 셀을 삭제하세요**
# >
# > 종속변수와 상관이 가장 높은 변수 **1개**로 단순회귀를 적합하고 요약 결과를 출력하세요.
# >
# > 이후 모든 개선은 **이 값 대비 개선폭**으로 이야기하게 됩니다.

# %% [markdown]
# **해석** — 베이스라인 R² = ( ), 조정 R² = ( ).
#
# >

# %% [markdown]
# ### 6-2. 다중회귀

# %% [markdown]
# > 🗑️ **작성 안내 — 완성 후 이 셀을 삭제하세요**
# >
# > #4-3에서 선정한 변수를 모두 투입해 다중회귀를 적합하고 요약 결과를 출력하세요.
# >
# > **요약 결과 읽는 법**
# >
# > | 항목 | 무엇을 보는가 |
# > |---|---|
# > | F검정의 p-value | 모형 전체가 유의한가 (< 0.05) |
# > | R² / **조정 R²** | 설명력. 변수 개수가 다르면 **조정 R²**로 비교 |
# > | AIC / BIC | 모형 비교 지표. **낮을수록** 좋음 |
# > | 각 변수의 계수와 p-value | 개별 변수의 영향력과 유의성 |
# > | Durbin-Watson | 잔차의 독립성 (#7에서 사용) |

# %% [markdown]
# **다중회귀 결과 해석**
#
# | 항목 | 값 | 판단 |
# |---|---|---|
# | F검정 p-value | | |
# | R² | | |
# | **조정 R²** | | 베이스라인 대비 개선폭: |
# | AIC / BIC | | |
# | p < 0.05 인 변수 | | |
# | p ≥ 0.05 인 변수 | | 제거 후보 |

# %% [markdown]
# ### 6-3. 변수 선택법

# %% [markdown]
# > 🗑️ **작성 안내 — 완성 후 이 셀을 삭제하세요**
# >
# > **전진선택 · 후진제거 · 단계적선택** 중 하나를 골라 적용하고, 고른 이유를 적으세요.
# >
# > 어떤 방법을 쓰든 **매 단계의 조정 R²와 AIC 변화를 기록**해야 합니다.
# > 그 기록이 아래 표가 됩니다.

# %% [markdown]
# 선택한 방법과 이유
#
# >

# %% [markdown]
# **선택 과정**
#
# | 단계 | 제거/추가 변수 | p-value | 조정 R² | AIC |
# |---|---|---|---|---|
# | 0 | (전체 투입) | — | | |
# | 1 | | | | |
# | 2 | | | | |

# %% [markdown]
# > 🗑️ **작성 안내 — 완성 후 이 셀을 삭제하세요**
# >
# > **선택 사항입니다.** #4-2에서 곡선 형태가 보였거나 두 변수의 상호작용이 의심될 때만 수행하세요.
# >
# > - **교호작용** — 한 변수의 효과가 다른 변수의 값에 따라 달라지는 경우
# > - **다항항** — 관계가 직선이 아니라 곡선인 경우
# >
# > 필요 없으면 아래 세 셀을 모두 삭제하세요.

# %% [markdown]
# ### 6-4. 교호작용 · 다항항 검토

# %% [markdown]
# **해석** — 조정 R²가 의미 있게 올랐는가? 채택 여부와 이유
#
# >

# %% [markdown]
# ---
# # #7. 모형 진단과 개선
#
# ### 7-1. 가정 검토

# %% [markdown]
# > 🗑️ **작성 안내 — 완성 후 이 셀을 삭제하세요**
# >
# > ⭐ **이 장이 선형회귀 포트폴리오의 핵심입니다.**
# > sklearn만 쓴 노트북과 갈리는 지점이므로 5가지를 모두 확인하고 **판정을 남기세요.**
# >
# > | 가정 | 확인 방법 | 판정 기준 |
# > |---|---|---|
# > | 선형성 | 잔차와 예측값의 산점도 | 0을 중심으로 무작위 분포 |
# > | 정규성 | 잔차의 Q-Q plot · 정규성 검정 | 점들이 직선 위, p > 0.05 |
# > | 등분산성 | Breusch-Pagan 검정 | p > 0.05 |
# > | 독립성 | Durbin-Watson 통계량 | 1.5 ~ 2.5 |
# > | 영향점 | Cook's distance | 4/n 을 넘는 관측치 확인 |
# >
# > 각 코드 셀 아래의 판정란에 **충족 / 위반 중 하나를 반드시 적으세요.**

# %% [markdown]
# > 🗑️ **작성 안내 — 완성 후 이 셀을 삭제하세요**
# >
# > **① 선형성** — 잔차와 예측값의 산점도를 그리세요.

# %% [markdown]
# **판정:** 충족 / 위반 — 근거:
#
# >

# %% [markdown]
# > 🗑️ **작성 안내 — 완성 후 이 셀을 삭제하세요**
# >
# > **② 정규성** — 잔차의 Q-Q plot을 그리고, 정규성 검정을 수행하세요.

# %% [markdown]
# **판정:** 충족 / 위반 — 근거:
#
# >

# %% [markdown]
# > 🗑️ **작성 안내 — 완성 후 이 셀을 삭제하세요**
# >
# > **③ 등분산성** — Breusch-Pagan 검정을 수행하세요.

# %% [markdown]
# **판정:** 충족 / 위반 — 근거:
#
# >

# %% [markdown]
# > 🗑️ **작성 안내 — 완성 후 이 셀을 삭제하세요**
# >
# > **④ 독립성** — Durbin-Watson 통계량을 확인하세요.

# %% [markdown]
# **판정:** 충족 / 위반 — 근거:
#
# >

# %% [markdown]
# > 🗑️ **작성 안내 — 완성 후 이 셀을 삭제하세요**
# >
# > **⑤ 영향점** — Cook's distance로 영향점을 찾으세요.

# %% [markdown]
# **판정:** 영향점 ( )건 — 처리 여부와 이유:
#
# >

# %% [markdown]
# > 🗑️ **작성 안내 — 완성 후 이 셀을 삭제하세요**
# >
# > 가정을 위반했을 때의 전형적인 조치입니다.
# >
# > | 위반 | 조치 |
# > |---|---|
# > | 선형성 | 변수 변환 · 다항항 추가 |
# > | 정규성 | 종속변수 로그변환 · 이상치 처리 |
# > | 등분산성 | 종속변수 로그변환 · 가중최소제곱 |
# > | 독립성 | 시계열 구조라면 다른 모형 고려 |
# >
# > ⚠️ **조치하지 못한 위반은 #8-3 한계에 반드시 명시하세요.** 숨기는 것보다 낫습니다.

# %% [markdown]
# ### 7-2. 가정 위반에 대한 조치
#
# | 위반 가정 | 조치 방법 | 실행 여부 |
# |---|---|---|
# | | | |

# %% [markdown]
# > 🗑️ **작성 안내 — 완성 후 이 셀을 삭제하세요**
# >
# > 조치를 반영해 모형을 다시 적합하고, 아래 수정 이력표를 채우세요.
# > **이 표가 "개선 과정"을 보여주는 증거입니다.**

# %% [markdown]
# ### 7-3. 모형 수정 이력
#
# | 모형 | 변경 내용 | 변경 이유 | 조정 R² | RMSE | AIC |
# |---|---|---|---|---|---|
# | v1 단순회귀 | 기준선 | — | | | |
# | v2 다중회귀 | 전체 변수 투입 | | | | |
# | v3 | | | | | |
# | v4 | | | | | |
#
# **최종 모형 선정 근거** (지표 + 가정 충족 + 해석 가능성)
#
# >

# %% [markdown]
# > 🗑️ **작성 안내 — 완성 후 이 셀을 삭제하세요**
# >
# > 아래 두 셀에서 최종 모형을 확정해 요약 결과를 출력하고, 예측 성능(RMSE·MAE)을 계산하세요.

# %% [markdown]
# ---
# # #8. 결과 해석
#
# ### 8-1. 회귀계수 해석

# %% [markdown]
# > 🗑️ **작성 안내 — 완성 후 이 셀을 삭제하세요**
# >
# > 아래 세 코드 셀에서 수행하세요.
# >
# > 1. **계수표 정리** — 변수별 계수 · 표준오차 · p-value · 95% 신뢰구간을 하나의 표로
# > 2. **표준화계수** — 모든 변수를 표준화(z-score)한 뒤 같은 모형을 다시 적합합니다.
# >    변수마다 단위가 달라 계수를 직접 비교할 수 없으므로, 스케일을 통일해 **영향력 크기를 비교**합니다.
# > 3. **표준화계수 막대그래프** — 영향력 순위 시각화

# %% [markdown]
# > 🗑️ **작성 안내 — 완성 후 이 셀을 삭제하세요**
# >
# > ⭐ **숫자가 아니라 문장으로 번역하세요.** 여기가 통계 실력이 드러나는 부분입니다.
# >
# > 작성 예시
# > > *"RM(방 개수)이 1개 증가하면 주택가격이 평균 3.8천 달러 상승한다 (p < .001)"*
# >
# > ⚠️ 로그변환한 변수는 **% 변화**로 해석해야 합니다.

# %% [markdown]
# **계수 해석**
#
# | 변수 | 계수 | 표준화계수 | p-value | 해석 (1단위 증가 시 효과) |
# |---|---|---|---|---|
# | | | | | |
# | | | | | |
# | | | | | |
#
# **영향력 순위 (표준화계수 기준):** 1위 ( ) > 2위 ( ) > 3위 ( )

# %% [markdown]
# > 🗑️ **작성 안내 — 완성 후 이 셀을 삭제하세요**
# >
# > #1에 적은 질문을 그대로 옮겨와 `질문 → 근거 → 답` 형식으로 답합니다.
# > 근거는 계수·유의성·조정 R² 같은 **이 노트북에서 실제로 구한 값**이어야 합니다.

# %% [markdown]
# ### 8-2. 질문별 답변과 가설 판정
#
# **Q1.**
# - 근거:
# - **답:**
#
# **Q2.**
# - 근거:
# - **답:**
#
# **가설 판정**
#
# | 가설 | 채택 / 기각 | 근거 |
# |---|---|---|
# | H1 | | |
# | H2 | | |
# | H3 | | |
#
# **핵심 인사이트**
#
# 1.
# 2.
# 3.

# %% [markdown]
# > 🗑️ **작성 안내 — 완성 후 이 셀을 삭제하세요**
# >
# > **정책 제언·사업 기획으로 확장하지 마세요.**
# > "이 모형의 쓰임새는 여기까지"라고 선을 긋는 것이 과장보다 신뢰를 줍니다.
# >
# > 한계에는 반드시 포함할 것
# > - #2-5에서 인지한 데이터 한계가 결과에 미친 영향
# > - #7에서 **조치하지 못한 가정 위반**
# > - 이 결과는 **인과가 아닌 연관 관계**이며, 데이터 범위 밖의 외삽은 불가

# %% [markdown]
# ### 8-3. 활용과 한계
#
# **활용**
#
# >
#
# **한계**
#
# - 데이터:
# - 가정:
# - 해석:
#
# **다음에 시도할 것**
#
# >

# %% [markdown]
# ---
# # #9. 참고자료
#
# ### 9-1. 데이터 출처
#
# - Kaggle 데이터셋:
# - URL:
# - 라이선스:
# - 참고한 커널·문서:

# %% [markdown]
# ### 9-2. 분석 환경

# %% [markdown]
# > ✅ 아래 셀은 완성되어 있습니다. **실행만** 하세요.

# %%
import sys, sklearn
print("Python      :", sys.version.split()[0])
print("pandas      :", pd.__version__)
print("numpy       :", np.__version__)
print("statsmodels :", sm.__version__)
print("scikit-learn:", sklearn.__version__)

# %% [markdown]
# > 🗑️ **작성 안내 — 완성 후 이 셀을 삭제하세요**
# >
# > #1에 적은 **"연습할 기법"에 대한 답**입니다. 이 한 쌍이 노트북을
# > "연습 기록"이 아니라 **"학습 성장의 증거"** 로 만듭니다. 3~5줄이면 충분합니다.

# %% [markdown]
# ### 9-3. 회고
#
# - **새로 익힌 기법:**
# - **막혔던 지점과 해결 방법:**
# - **다음 데이터셋에서 보완할 점:**

# %% [markdown]
# > 🗑️ **작성 안내 — 완성 후 이 셀을 삭제하세요**
# >
# > # ✅ 제출 전 체크리스트
# >
# > - [ ] **🗑️ 표시된 안내 셀을 모두 삭제**했는가
# > - [ ] 모든 코드 셀 아래에 해석 한 줄이 있는가
# > - [ ] 남은 빈칸 `( )` 이 없는가
# > - [ ] #1이 화면 한 장을 넘지 않는가
# > - [ ] 산점도로 **선형성을 확인한 뒤** 선형회귀를 선택했는가
# > - [ ] VIF를 확인하고 다중공선성을 처리했는가
# > - [ ] **5가지 가정 검토**에 모두 판정을 남겼는가
# > - [ ] 가정 위반에 조치했거나, 못 했다면 #8-3에 명시했는가
# > - [ ] 계수를 **도메인 언어로 번역**했는가 (숫자 나열 ✗)
# > - [ ] 단순회귀 베이스라인 대비 개선폭을 숫자로 말했는가
# > - [ ] #1의 Q1·Q2가 #8-2에서 모두 답변되었는가
# > - [ ] #0 요약을 마지막에 채웠는가
# > - [ ] `Restart & Run All` 후 **출력이 저장된 상태**로 커밋했는가
# > - [ ] 파일명: `회귀_데이터셋명_분석.ipynb`
