# %% [markdown]
# # [LAB-06] 8. Bar・Count Plot
#
# ## #01. 준비작업
#
# ### 1. 패키지 가져오기
#
# - numpy 패키지가 함께 사용된다.

# %%
from jussam import load_data
from helper import *
import seaborn as sb
import numpy as np
# Out:
# 📦 연세대학교 주영아 교수가 제작한 라이브러리를 사용중입니다.
# 📧 Email(1): j.purplerose@yonsei.ac.kr
# 📧 Email(2): j.purplerose@gmail.com
# 📝 Website: https://juyounga.kr/

# %% [markdown]
# ### 2. 데이터 가져오기

# %%
origin = load_data('penguins')
origin
# Out:
# 📚 남극 팔머 군도의 펭귄 3종에 대해 신체 치수와 서식지 정보(출처: https://www.kaggle.com/datasets/larsen0966/penguins)
#
#     field              description
# --  -----------------  -------------
#  0  species            팽귄 종
#  1  island             서식지
#  2  bill_length_mm     부리 길이
#  3  bill_depth_mm      부리 두께
#  4  flipper_length_mm  날개 길이
#  5  body_mass_g        몸무게
#  6  sex                성별
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen          39.100         18.700                181
# 1    Adelie  Torgersen          39.500         17.400                186
# 2    Adelie  Torgersen          40.300         18.000                195
# 3    Adelie  Torgersen          36.700         19.300                193
# 4    Adelie  Torgersen          39.300         20.600                190
# ..      ...        ...             ...            ...                ...
# 329  Gentoo     Biscoe          47.200         13.700                214
# 330  Gentoo     Biscoe          46.800         14.300                215
# 331  Gentoo     Biscoe          50.400         15.700                222
# 332  Gentoo     Biscoe          45.200         14.800                212
# 333  Gentoo     Biscoe          49.900         16.100                213
#
#      body_mass_g     sex
# 0           3750    MALE
# 1           3800  FEMALE
# 2           3250  FEMALE
# 3           3450  FEMALE
# 4           3650    MALE
# ..           ...     ...
# 329         4925  FEMALE
# 330         4850  FEMALE
# 331         5750    MALE
# 332         5200  FEMALE
# 333         5400    MALE
#
# [333 rows x 7 columns]

# %% [markdown]
# ## #02. BarPlot
#
# ### 1. 집단별 세로 평균 그래프
#
# - 팽귄 종에 따른 몸무게 평균
#   - 집단별 요약 통계 시각화에서 가장 기본이 되는 형태
#   - 범주형 분석에서 가장 표준적으로 사용되는 그래프

# %%
# 그래프 초기화 
fig, ax = my_plot.init(title="펭귄의 종별 평균 몸무게", xlabel="종", ylabel="몸무게 (g)")

# barplot 그리기
sb.barplot(data=origin, x="species", y="body_mass_g")

# 그래프 꾸미기
my_plot.show()

# %% [markdown]
# #### 💡 인사이트
#
# - 🐧 종별 평균 몸무게는 Gentoo가 가장 높게 나타남(약 5,100g 수준).
# - 📊 Adelie와 Chinstrap의 평균 몸무게는 서로 매우 유사함(둘 다 약 3,700g대, Chinstrap이 소폭 높음).
# - 📏 Gentoo와 나머지 두 종(Adelie/Chinstrap) 사이 평균 몸무게 차이가 크게 보임(대략 1,300g 내외).
# - 🎯 오차막대(error bar) 폭이 전반적으로 크지 않아, 각 종 평균 추정값이 비교적 안정적으로 표현됨.
# - 🧭 이 그래프 기준으로는 종(species)에 따라 몸무게 수준이 뚜렷하게 구분되는 패턴이 확인됨.

# %% [markdown]
# ### 2. 집단별 가로 평균 그래프
#
# - x 파라미터에 수치형 변수, y 파라미터에 범주형 변수를 설정한다.

# %%
# 그래프 초기화
fig, ax = my_plot.init(title="펭귄의 종별 평균 몸무게", xlabel="몸무게(g)", ylabel="종")

# barplot 그리기
sb.barplot(data=origin, x="body_mass_g", y="species", palette="Set2", hue="species")

# 그래프 표시하기
my_plot.show()

# %% [markdown]
# ### 3. 다양한 집계 방법 사용하기
#
# - estimator 파라미터에 요약 함수를 지정한다.

# %%
# 그래프 초기화
fig, ax = my_plot.init(title="펭귄의 종별 최대 몸무게", xlabel="종", ylabel="최대 몸무게 (g)")

# barplot 그리기
sb.barplot(data=origin, x="species", y="body_mass_g", hue="species", estimator=np.max, order=['Gentoo', 'Adelie', 'Chinstrap'])
# 그래프 표시하기
my_plot.show()

# %% [markdown]
# #### 💡 인사이트
#
# - 🐧 종별 최대 몸무게는 Gentoo가 가장 높게 나타남(약 6,300g 수준).
# - 📊 Chinstrap과 Adelie의 최대 몸무게는 서로 매우 비슷한 수준임(둘 다 약 4,800g 내외).
# - 📏 Gentoo와 Chinstrap/Adelie 사이 최대 몸무게 차이가 크게 보임(약 1,500g 안팎).
# - 🎯 오차막대 기준으로 Chinstrap의 변동 폭이 가장 크게 보이고, Adelie는 가장 작게 보임.
# - 🧭 제시된 순서(Gentoo → Chinstrap → Adelie)에서도 최대 몸무게의 우위는 Gentoo가 뚜렷하게 유지됨.

# %% [markdown]
# ### 4. 범주에 따른 구분
#
# - x축과 hue에 각각 다른 범주형 컬럼을 지정하여 x축에서 구분한 범주에 대하여, hue에 지정한 범주별로 한 번 더 구분한다.

# %%
# 그래프 초기화
fig, ax = my_plot.init(title="펭귄의 종에 대한 성별 평균 몸무게")

# barplot 그리기
sb.barplot(
    data=origin,       # 사용할 데이터프레임
    x="species",       # x축 : 범주형 변수
    y="body_mass_g",   # y축 : 수치형 변수
    hue="sex",         # 구분할 범주형 변수
    palette="pastel"   # 색상 팔레트
)

# 그래프 표시하기
my_plot.show()

# %% [markdown]
# #### 💡 인사이트
#
# - 🐧 모든 종에서 MALE 평균 몸무게가 FEMALE보다 높게 나타남.
# - 📊 종 내 성별 평균 비교 시, 성별 차이는 Gentoo에서 가장 크게 보이고 Chinstrap에서 가장 작게 보임.
# - 📏 Gentoo는 MALE/FEMALE 모두에서 평균 몸무게가 가장 높음.
# - 🔍 Adelie와 Chinstrap는 MALE 기준으로는 비슷한 수준이고, FEMALE 기준으로도 큰 차이 없이 근접한 수준임.
# - 🎯 막대 높이 기준으로 보면, 종 효과(특히 Gentoo)와 성별 효과(MALE > FEMALE)가 동시에 뚜렷하게 관찰됨.

# %% [markdown]
# ## #03. CountPlot (빈도 그래프)
#
# - barplot의 estimator 파라미터가 `len`으로 고정되어 있는 형태
#   - x나 y파라미터 중 하나만 명목형 변수로 설정한다.
#   - 설정하는 파라미터에 따라 가로/세로 형태가 결정된다.

# %%
# 그래프 초기화
fig, ax = my_plot.init(title="펭귄의 종별 개체수", xlabel="종", ylabel="개체수")

# countplot 그리기
sb.countplot(data=origin, x="species", hue='sex', palette="spring")

# 그래프 표시하기
my_plot.show()

# %% [markdown]
# #### 💡 인사이트
#
# - 🐧 종별 전체 개체수는 Adelie가 가장 많고, Chinstrap이 가장 적으며, Gentoo는 그 중간 수준임.
# - ⚖️ Adelie와 Chinstrap에서는 MALE/FEMALE 막대 높이가 거의 동일해 성별 개체수 균형이 뚜렷함.
# - 📊 Gentoo에서는 MALE이 FEMALE보다 소폭 많아, 세 종 중 성별 차이가 가장 눈에 띄게 나타남.
# - 🔎 종 내 성별 비교 기준으로 보면, 뚜렷한 성별 불균형은 전반적으로 크지 않고 대부분 비슷한 분포를 보임.
# - 🎯 countplot 결과 기준으로 데이터 분포의 핵심은 종별 규모 차이(Adelie > Gentoo > Chinstrap)이며, 성별 차이는 제한적임.

# %% [markdown]
# ## #04. 모듈화 기능 확인
#
# ### 1. BarPlot

# %%
my_plot.barplot(data=origin, title="펭귄의 종별 평균 몸무게", x="species", y="body_mass_g", xlabel="종", ylabel="몸무게 (g)", hue="sex", estimator=np.mean, palette="Set2")

# %% [markdown]
# ### 2. CountPlot

# %%
my_plot.countplot(data=origin, x="species", hue="sex", palette="tab20",
                   title="펭귄의 종별 개체수", xlabel="종", ylabel="개체수")

# %% [markdown]
# #### 연습문제. 종사자 규모별 업체수로부터 인사이트 발굴
# ##### jobs_by_scale 데이터 셋이용
# ##### 순서
# ##### 1. 'jobs_by_scale' 데이터셋을 불러와 데이터의 구조(컬럼, 행)를 확인한다.
# ##### 2. 'melt'함수를 사용해 두개의 년도 컬럼을 하나의 '년도'컬럼과 '종사자수'값 컬럼으로 long형태로 재구조화한다. (식별 변수: '종사자규모별')
# ##### 3. 재구조화된 DataFrame을 사용해 막대그래프를 그린다. (x축: 종사자 규모, y축: 종사자 수)
# ##### 4. 'hue'옵션에 '년도'를 지정하여 2015년과 2016년 막대가 나란히 표시되도록 한다.
# ##### 5. 팔레트,x축-y축 라벨등 시각화 옵션을 지정하여 그래프를 완성한다.

# %%
# 0. 필요한 모듈 불러오기
from jussam import load_data
from helper import *
import seaborn as sb
import numpy as np
from pandas import pivot_table, melt

# %%
# 1. 데이터셋 불러오기 및 정보 확인
df = load_data('jobs_by_scale')
df.info()
df
# Out:
# 📚 종사자 규모별 업체수를 2015년과 2016년도에 걸쳐 조사한 데이터 (출처: 국가통계포털)
# <class 'pandas.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   종사자규모별  9 non-null      str
#  1   2015    9 non-null      float64
#  2   2016    9 non-null      float64
# dtypes: float64(2), str(1)
# memory usage: 428.0 bytes
#      종사자규모별    2015    2016
# 0      1~4명 553.500 576.700
# 1      5~9명 211.600 216.800
# 2    10~29명 194.700 195.500
# 3    30~49명 227.400 227.400
# 4    50~99명 152.800 155.700
# 5  100~199명 221.900 220.600
# 6  200~299명  80.900  81.000
# 7  300~999명 100.500  99.300
# 8  1000명 이상 557.600 549.700

# %%
df1 = melt(df, id_vars="종사자규모별", var_name="년도", value_name="종사자수")
df1
# Out:
#       종사자규모별    년도    종사자수
# 0       1~4명  2015 553.500
# 1       5~9명  2015 211.600
# 2     10~29명  2015 194.700
# 3     30~49명  2015 227.400
# 4     50~99명  2015 152.800
# 5   100~199명  2015 221.900
# 6   200~299명  2015  80.900
# 7   300~999명  2015 100.500
# 8   1000명 이상  2015 557.600
# 9       1~4명  2016 576.700
# 10      5~9명  2016 216.800
# 11    10~29명  2016 195.500
# 12    30~49명  2016 227.400
# 13    50~99명  2016 155.700
# 14  100~199명  2016 220.600
# 15  200~299명  2016  81.000
# 16  300~999명  2016  99.300
# 17  1000명 이상  2016 549.700

# %%
my_plot.barplot(df1, x='종사자규모별', y='종사자수', xlabel="종사자규모", ylabel="종사자수", hue="년도", palette="GnBu")

# %% [markdown]
# #### 문 제 1. 2015년과 2016년 모두 막대의 높이가 가장 낮게 나타나, 종사자 수가 가장 적은 종사자 규모구간은?
# ###### 200~299명의 바그래프가 가장 낮게 측정이 되었다.
# #### 문 제 2. 2015년에는 종사자 수 1위였으나, 2016년에는 1~4명 규모에게 1위를 빼앗긴 종사자 규모 구간은?
# ###### 1000명이상에서 2015년에 1위였으나 2016년에 1~4명 규모에게 1위를 빼앗긴걸로 관측됨.
# #### 문 제 3. 2015년 대비 2016년에 종사자 수 증가폭이 가장 크게 나타난 종사자 규모 구간은?
# ###### 1~4명 bar에서 큰 폭으로 변화한게 관측됨.
