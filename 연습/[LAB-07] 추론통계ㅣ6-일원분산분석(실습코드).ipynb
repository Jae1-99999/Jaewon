# %% [markdown]
# # [LAB-07] 6. 일원분산분석 (One-way ANOVA)
#
# ## #01. 준비작업
#
# ### 1. 패키지 설치
#
# `pingouin` 패키지와 `statsmodels` 패키지의 설치가 필요하다

# %%
# !pip install --upgrade pingouin
# Out:
# Requirement already satisfied: pingouin in C:\Users\ITWILL\AppData\Local\Programs\Python\Python313\Lib\site-packages (0.6.1)
# Requirement already satisfied: matplotlib in C:\Users\ITWILL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pingouin) (3.11.0)
# Requirement already satisfied: numpy>=1.22.4 in C:\Users\ITWILL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pingouin) (2.4.6)
# Requirement already satisfied: pandas>=2.1.1 in C:\Users\ITWILL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pingouin) (3.0.1)
# Requirement already satisfied: pandas_flavor in C:\Users\ITWILL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pingouin) (0.8.1)
# Requirement already satisfied: scikit-learn>=1.2.2 in C:\Users\ITWILL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pingouin) (1.9.0)
# Requirement already satisfied: scipy>=1.10.0 in C:\Users\ITWILL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pingouin) (1.18.0)
# Requirement already satisfied: seaborn in C:\Users\ITWILL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pingouin) (0.13.2)
# Requirement already satisfied: statsmodels>=0.14.1 in C:\Users\ITWILL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pingouin) (0.14.6)
# Requirement already satisfied: tabulate in C:\Users\ITWILL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pingouin) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\ITWILL\AppData\Roaming\Python\Python313\site-packages (from pandas>=2.1.1->pingouin) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\ITWILL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas>=2.1.1->pingouin) (2025.3)
# Requirement already satisfied: six>=1.5 in C:\Users\ITWILL\AppData\Roaming\Python\Python313\site-packages (from python-dateutil>=2.8.2->pandas>=2.1.1->pingouin) (1.17.0)
# Requirement already satisfied: joblib>=1.4.0 in C:\Users\ITWILL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from scikit-learn>=1.2.2->pingouin) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in C:\Users\ITWILL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from scikit-learn>=1.2.2->pingouin) (2.18.1)
# Requirement already satisfied: threadpoolctl>=3.5.0 in C:\Users\ITWILL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from scikit-learn>=1.2.2->pingouin) (3.6.0)
# Requirement already satisfied: patsy>=0.5.6 in C:\Users\ITWILL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from statsmodels>=0.14.1->pingouin) (1.0.2)
# Requirement already satisfied: packaging>=21.3 in C:\Users\ITWILL\AppData\Roaming\Python\Python313\site-packages (from statsmodels>=0.14.1->pingouin) (26.0)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\ITWILL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib->pingouin) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\ITWILL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib->pingouin) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\ITWILL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib->pingouin) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\ITWILL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib->pingouin) (1.5.0)
# Requirement already satisfied: pillow>=9 in C:\Users\ITWILL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib->pingouin) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in C:\Users\ITWILL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib->pingouin) (3.3.2)
# Requirement already satisfied: xarray in C:\Users\ITWILL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas_flavor->pingouin) (2026.4.0)
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install --upgrade statsmodels
# Out:
# Requirement already satisfied: statsmodels in C:\Users\ITWILL\AppData\Local\Programs\Python\Python313\Lib\site-packages (0.14.6)
# Requirement already satisfied: numpy<3,>=1.22.3 in C:\Users\ITWILL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from statsmodels) (2.4.6)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in C:\Users\ITWILL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from statsmodels) (1.18.0)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in C:\Users\ITWILL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from statsmodels) (3.0.1)
# Requirement already satisfied: patsy>=0.5.6 in C:\Users\ITWILL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from statsmodels) (1.0.2)
# Requirement already satisfied: packaging>=21.3 in C:\Users\ITWILL\AppData\Roaming\Python\Python313\site-packages (from statsmodels) (26.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\ITWILL\AppData\Roaming\Python\Python313\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\ITWILL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.3)
# Requirement already satisfied: six>=1.5 in C:\Users\ITWILL\AppData\Roaming\Python\Python313\site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ### 2. 라이브러리 참조

# %%
from jussam import load_data
from helper import *
from pandas import pivot_table

# 분산분석을 위한 라이브러리
from scipy.stats import f_oneway
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm
from pingouin import anova
from pingouin import welch_anova
# Out:
# 📦 연세대학교 주영아 교수가 제작한 라이브러리를 사용중입니다.
# 📧 Email(1): j.purplerose@yonsei.ac.kr
# 📧 Email(2): j.purplerose@gmail.com
# 📝 Website: https://juyounga.kr/

# %% [markdown]
# ### 3. 데이터 가져오기
#
# `tree_weight` 데이터셋은 소나무 품종별 무게를 조사한 데이터이다. 소나무 품종별로 평균 무게에 차이가 있는지 분석하라.

# %%
origin = load_data('tree_weight')
origin
# Out:
# 📚 소나무 품종별 무게를 조사한 데이터 (출처: 방송통신대학교 통계학개론)
#     weight group
# 0    4.170     A
# 1    5.580     A
# 2    5.180     A
# 3    6.110     A
# 4    4.500     A
# 5    4.610     A
# 6    5.170     A
# 7    4.530     A
# 8    5.330     A
# 9    5.140     A
# 10   4.810     B
# 11   4.170     B
# 12   4.410     B
# 13   3.590     B
# 14   5.870     B
# 15   3.830     B
# 16   6.030     B
# 17   4.890     B
# 18   4.320     B
# 19   4.690     B
# 20   6.310     C
# 21   5.120     C
# 22   5.540     C
# 23   5.500     C
# 24   5.370     C
# 25   5.290     C
# 26   4.920     C
# 27   6.150     C
# 28   5.800     C
# 29   5.260     C

# %% [markdown]
# ## #02. 데이터 분포 및 가정 확인
#
# ### 1. 데이터 분포

# %%
my_plot.kdeplot(origin, x='weight', hue='group', fill=True, meanline=True, clevel=0.95)

# %% [markdown]
# #### 💡인사이트
#
# - **분산분석의 동기**: 평균이 B(4.66) < A(5.03) < C(5.53)로 벌어져 있어 집단 간 변동을 검정할 가치가 있음
# - **정규성 가정**: 세 분포가 종 모양 대칭 → normaltest로 확인
# - **등분산성 가정**: 분포 폭이 비슷 → Bartlett로 확인, 위반 시 Welch-ANOVA
# - **겹침**: 분포가 많이 겹쳐 눈으로 단정 불가, F·p로 판단 필요
# - **사후검정 예고**: B와 C는 신뢰수준 영역이 거의 안 겹치나 A는 애매 → 어느 쌍이 다른지는 사후검정 필요

# %% [markdown]
# ### 2. long 타입 데이터로 변환
#
# - 가설검정의 가정 확인을 위해 long 타입의 데이터를 wide 타입으로 변환해야 한다.

# %%
df_wide = my_prep.long2wide(origin, hue='group', values='weight')
df_wide
# Out:
#       A     B     C
# 0 4.170 4.810 6.310
# 1 5.580 4.170 5.120
# 2 5.180 4.410 5.540
# 3 6.110 3.590 5.500
# 4 4.500 5.870 5.370
# 5 4.610 3.830 5.290
# 6 5.170 6.030 4.920
# 7 4.530 4.890 6.150
# 8 5.330 4.320 5.800
# 9 5.140 4.690 5.260

# %% [markdown]
# ### 3. 가설검정의 가정 확인

# %%
my_stats.test_assumptions(df_wide)
# Out:
#                 test  statistic  p-value  result
# field
# A         normaltest      0.233    0.890    True
# B         normaltest      0.968    0.616    True
# C         normaltest      1.013    0.603    True
# Bartlett   equal_var      2.879    0.237    True

# %% [markdown]
# > 정규성과 등분산성을 모두 충족한다.

# %% [markdown]
# ## #03. 일원분산분석
#
# ### 1. scipy 패키지를 사용하는 경우
#
# - wide 타입의 데이터프레임을 사용해야 한다.
# - 등분산성을 만족하지 않을 경우 `equal_var=False` 파라미터를 함께 설정하여 Welch-Anova로 전환한다.
#
# | 구분 | 수식 | 내용 |
# |---|---|---|
# | 귀무가설($H_0$) | $\mu(A) = \mu(B) = \mu(C)$ | 세 품종간의 평균 무게는 차이가 없다. |
# | 대립가설($H_1$) | $\text{Not all population means are equal.}$ | 적어도 한 품종의 평균 무게는 다른 품종과 차이가 있다. |

# %%
s, p = f_oneway(df_wide['A'], df_wide['B'], df_wide['C'], equal_var=True)
"statistic: {0:.3f}, p-value: {1:.3f}".format(s, p)
# Out:
# 'statistic: 4.846, p-value: 0.016'

# %% [markdown]
# > 세 종류의 소나무 품종의 평균 무게에 대해 분산분석을 수행한 결과 귀무가설을 기각하고 대립가설을 채택한다($p < 0.05$).
# > 즉, 세 종류의 소나무 품종 중에서 적어도 한 품종 이상은 평균 무게가 다르다.

# %% [markdown]
# ### 2. `statsmodels` 패키지 사용
#
# - long 타입의 데이터프레임을 사용해야 한다.
#   - 데이터가 등분산성을 만족하지 않을 경우 **anova_lm()** 함수에 **robust='hc3'** 파라미터를 전달하여 **Huber-White** 추정치를 사용한다.
#   - 원래는 **Welch-ANOVA**로 검정해야 하지만 statsmodels 패키지는 Welch-ANOVA를 지원하지 않고, Welch-ANOVA의 근사치를 제공하는 Robust ANOVA를 제공한다.
#   - 그래서 **statsmodels를 통한 분산분석은 추천하지 않는다**.

# %%
# 연속형변수이름 ~ C(그룹변수이름)
lm = ols('weight ~ C(group)', data=origin).fit()
anova_result = anova_lm(lm)
anova_result
# Out:
#              df  sum_sq  mean_sq     F  PR(>F)
# C(group)  2.000   3.766    1.883 4.846   0.016
# Residual 27.000  10.492    0.389   NaN     NaN

# %% [markdown]
# ### 3. pingouin 패키지 사용 (1) - 등분산성을 충족하는 경우
#
# - long 타입의 데이터프레임을 사용해야 한다.

# %%
anova_result = anova(data=origin, dv='weight', between='group')
anova_result
# Out:
#   Source  ddof1  ddof2     F  p_unc   np2
# 0  group      2     27 4.846  0.016 0.264

# %% [markdown]
# ### 4. pingouin 패키지 사용 (2) - 등분산성을 충족하지 않는 경우
#
# - 데이터가 등분산성을 만족하지 않을 경우 `anova()` 함수 대신 같은 패키지에 있는 `welch_anova()` 함수를 사용한다.
#
# > 이 예제는 등분산성을 충족하는 데이터 이지만 코드를 소개하기 위해 실습함

# %%
welch_anova(data=origin, dv='weight', between='group')
# Out:
#   Source  ddof1  ddof2     F  p_unc   np2
# 0  group      2 17.128 5.181  0.017 0.264

# %% [markdown]
# ## #04. 모듈화 기능 확인

# %%
my_stats.anova_oneway(origin, y='weight', between='group')
# Out:
#           test Source  ddof1  ddof2     F  p_unc   np2 effect_size
# 0  welch-anova  group      2 17.128 5.181  0.017 0.264       Large

# %% [markdown]
# #### 💡인사이트
#
# - **검정 선택**: `test=anova` → 등분산성을 충족하여 일반 일원분산분석을 자동 적용 (위반 시 `welch_anova`로 전환)
# - **유의성**: F(2, 27)=4.846, p=0.016 < 0.05 → 귀무가설 기각. **세 품종 중 적어도 한 품종의 평균 무게는 다르다**
# - **효과크기**: η²ₚ(np2)=0.264 → `Large` (품종 차이가 무게 변동의 약 26%를 설명, 통계적 유의성을 넘어 실질적으로도 큰 효과)
# - **다음 단계**: ANOVA는 "어딘가 차이가 있다"까지만 말해주므로, **어느 쌍이 다른지는 사후검정(Tukey HSD 등)**으로 확인 필요

# %% [markdown]
# ## 일원 분산분석 챌린지
# #### 문제1
# #### reading 데이터셋은 유아들을 대상으로 세 가지 읽는 방법을 비교,실험하여 얻은 독서평가 점수 데이터
# #### 세 방법에 통계적으로 유의한 차이가 있는지 검정
