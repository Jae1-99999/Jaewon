# %% [markdown]
# # [LAB-06] 캡스톤 (1) - WAGE 데이터셋 (ADsP 기출)
#
# 1. 각 문제의 질문을 읽고, **어떤 그래프가 답을 찾기에 적절한지 스스로 판단**하여 직접 시각화하세요.
# 2. 그래프를 보고 객관식 보기 중 정답을 고르세요.
#
# ## 준비작업
#
# ### 1. 라이브러리 참조

# %%
from jussam import load_data
from helper import my_plot, my_qtcheck
import numpy as np
# Out:
# 📦 연세대학교 주영아 교수가 제작한 라이브러리를 사용중입니다.
# 📧 Email(1): j.purplerose@yonsei.ac.kr
# 📧 Email(2): j.purplerose@gmail.com
# 📝 Website: https://juyounga.kr/

# %% [markdown]
# ### 2. 데이터 가져오기

# %%
origin = load_data('wage')
origin
# Out:
# 📚 경제 및 노동 시장에 관련된 정보를 담고 있는 데이터셋(출처: ADsP 기출문제)
#
#     field       description
# --  ----------  ------------------
#  0  year        년도
#  1  age         나이
#  2  maritl      결혼여부
#  3  race        근로자의 인종
#  4  education   교육수준
#  5  region      지역
#  6  jobclass    직군
#  7  health      건상상태
#  8  health_ins  건강보험 가입 여부
#  9  logwage     임금(로그값)
# 10  wage        임금
#       year  age            maritl      race        education  \
# 0     2006   18  1. Never Married  1. White     1. < HS Grad
# 1     2004   24  1. Never Married  1. White  4. College Grad
# 2     2003   45        2. Married  1. White  3. Some College
# 3     2003   43        2. Married  3. Asian  4. College Grad
# 4     2005   50       4. Divorced  1. White       2. HS Grad
# ...    ...  ...               ...       ...              ...
# 2995  2008   44        2. Married  1. White  3. Some College
# 2996  2007   30        2. Married  1. White       2. HS Grad
# 2997  2005   27        2. Married  2. Black     1. < HS Grad
# 2998  2005   27  1. Never Married  1. White  3. Some College
# 2999  2009   55      5. Separated  1. White       2. HS Grad
#
#                   region        jobclass          health health_ins  logwage  \
# 0     2. Middle Atlantic   1. Industrial       1. <=Good      2. No    4.318
# 1     2. Middle Atlantic  2. Information  2. >=Very Good      2. No    4.255
# 2     2. Middle Atlantic   1. Industrial       1. <=Good     1. Yes    4.875
# 3     2. Middle Atlantic  2. Information  2. >=Very Good     1. Yes    5.041
# 4     2. Middle Atlantic  2. Information       1. <=Good     1. Yes    4.318
# ...                  ...             ...             ...        ...      ...
# 2995  2. Middle Atlantic   1. Industrial  2. >=Very Good     1. Yes    5.041
# 2996  2. Middle Atlantic   1. Industrial  2. >=Very Good      2. No    4.602
# 2997  2. Middle Atlantic   1. Industrial       1. <=Good      2. No    4.193
# 2998  2. Middle Atlantic   1. Industrial  2. >=Very Good     1. Yes    4.477
# 2999  2. Middle Atlantic   1. Industrial       1. <=Good     1. Yes    4.505
#
#         wage
# 0     75.043
# 1     70.476
# 2    130.982
# 3    154.685
# 4     75.043
# ...      ...
# 2995 154.685
# 2996  99.689
# 2997  66.229
# 2998  87.981
# 2999  90.482
#
# [3000 rows x 11 columns]

# %%
my_plot.countplot(origin, x='maritl', title='결혼여부 인원수', xlabel='결혼여부', ylabel='count', palette='Set2')
# Out:
# c:\Users\ITWILL\Desktop\주영아강사님\연습\helper\my_plot.py:235: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.countplot(data=data, x=x, y=y, hue=hue, order=order, palette=palette, ax=ax)

# %% [markdown]
# ## 정답
# #### 2.Married

# %% [markdown]
# ## 문제 2. 임금(`wage`)의 분포 형태로 가장 적절한 설명은?
#
# ① 좌우 대칭  ② 오른쪽으로 꼬리가 긴(우편향) 분포  ③ 왼쪽으로 꼬리가 긴(좌편향) 분포  ④ 균등(평탄) 분포
#
# > 💡 **힌트**: 히스토그램 또는 박스플롯
# > 🎯 **ADsP 개념**: 분포의 형태 · 왜도(skewness) · 평균과 중앙값의 관계

# %%
my_plot.histplot(data=origin, x='wage', xlabel='임금', ylabel='임금분포', title='임금분포', kde=True, palette='Set2')
# Out:
# c:\Users\ITWILL\Desktop\주영아강사님\연습\helper\my_plot.py:134: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sb.histplot(data=data, x=x, hue=hue, linewidth=linewidth,

# %% [markdown]
# ## 정답
# #### 오른쪽 꼬리가 긴 우편향

# %% [markdown]
# ## 문제 3. 나이(`age`)의 중앙값(median)에 가장 가까운 값은?
#
# ① 34  ② 42  ③ 51  ④ 60
#
# > 💡 **힌트**: 박스플롯 또는 히스토그램
# > 🎯 **ADsP 개념**: 대푯값(중앙값) · 사분위수

# %%
my_plot.kdeplot(data=origin, x='age', title='나이 분포도', xlabel='나이', meanline=True)
my_plot.boxplot(data=origin, x='age', title='나이 분포도', xlabel='나이')

# %% [markdown]
# ## 정답
# #### 중앙값이 42.4147이 나와서 약 42

# %% [markdown]
# ## 문제 4. `age`, `wage`, `logwage` 세 변수 중, 상단에 이상치(극단적으로 큰 값)가 가장 두드러지게 나타나는 변수는?
#
# ① age  ② wage  ③ logwage  ④ 모두 동일하다
#
# > 💡 **힌트**: 박스플롯 (세 변수를 개별적으로)
# > 🎯 **ADsP 개념**: 이상치(outlier) 탐지 · 상자그림(IQR 기준)

# %%
df = origin[['age', 'wage', 'logwage']]
my_plot.boxplot(data=df, title='age,wage,logwage의 변수 분포도')

# %% [markdown]
# ## 정답
# #### wage의 이상치 분포도가 매우 많음

# %% [markdown]
# ## 문제 5. `wage`와 `logwage` 중, 분포가 더 좌우 대칭에 가까운 변수는?
#
# ① wage  ② logwage  ③ 둘이 완전히 동일  ④ 판단할 수 없음
#
# > 💡 **힌트**: 히스토그램 또는 박스플롯 (두 변수 비교)
# > 🎯 **ADsP 개념**: 변수 변환(로그 변환) · 분포의 정규성

# %%
my_plot.histplot(data=origin, x='wage', title='wage분포', kde=True)
my_plot.histplot(data=origin, x='logwage', title='logwage 분포', kde=True)

# %% [markdown]
# ## 정답
# #### logwage가 더 좌우대칭에 가깝다

# %% [markdown]
# ## 문제 6. 교육 수준(`education`)과 임금(`wage`)의 관계로 옳은 것은?
#
# ① 교육 수준이 높을수록 임금이 높다  ② 교육 수준이 높을수록 임금이 낮다  ③ 관계가 없다  ④ 고졸에서 임금이 가장 높다
#
# > 💡 **힌트**: 막대그래프 또는 박스플롯(교육수준별 wage)
# > 🎯 **ADsP 개념**: 범주별 집단 비교 · 순서형 변수와 연속형의 관계

# %%
my_plot.barplot(data=origin, x= 'education', y='wage', title='교육 수준과 임금과의 관계', xlabel='교육 수준', ylabel='임금', palette='Set2')
# Out:
# c:\Users\ITWILL\Desktop\주영아강사님\연습\helper\my_plot.py:215: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.barplot(data=data, x=x, y=y, hue=hue, estimator=estimator, order=order, palette=palette, ax=ax)

# %% [markdown]
# ## 정답
# #### 교육수준이 높을수록 임금이 높다

# %% [markdown]
# ## 문제 7. 직군(`jobclass`)에 따른 임금 비교로 옳은 것은?
#
# ① 생산직(Industrial)이 더 높다  ② 사무직(Information)이 더 높다  ③ 차이가 없다  ④ 생산직이 2배 높다
#
# > 💡 **힌트**: 박스플롯 / 바이올린플롯 / 막대그래프(직군별 wage)
# > 🎯 **ADsP 개념**: 두 집단의 중심·분포 비교

# %%
my_plot.barplot(data=origin, x='jobclass', y='wage', title='직군에 따른 임금 비교', estimator=np.mean, palette='Set2')
# Out:
# c:\Users\ITWILL\Desktop\주영아강사님\연습\helper\my_plot.py:215: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.barplot(data=data, x=x, y=y, hue=hue, estimator=estimator, order=order, palette=palette, ax=ax)

# %% [markdown]
# ## 정답
# #### 사무직이 생산직보다 임금이 높다

# %% [markdown]
# ## 문제 8. 인종(`race`)별 평균 임금이 가장 높은 집단은?
#
# ① White  ② Black  ③ Asian  ④ Other
#
# > 💡 **힌트**: 막대그래프 또는 박스플롯(인종별 wage)
# > 🎯 **ADsP 개념**: 빈도(표본 수)와 평균(대푯값)의 구분

# %%
my_plot.barplot(data=origin, x='race', y='wage', estimator=np.mean, title='인종별 평균임금', palette='Set2')
# Out:
# c:\Users\ITWILL\Desktop\주영아강사님\연습\helper\my_plot.py:215: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.barplot(data=data, x=x, y=y, hue=hue, estimator=estimator, order=order, palette=palette, ax=ax)

# %% [markdown]
# ## 정답
# #### Asian인이 다른 인종보다 임금평균이 더 높다

# %% [markdown]
# ## 문제 9. 직군(`jobclass`)과 인종(`race`)을 함께 고려할 때, 사무직(Information)에서 200 이상의 고임금 비중이 특히 두드러지는 인종은?
#
# ① White  ② Black  ③ Asian  ④ Other
#
# > 💡 **힌트**: 바이올린플롯 (x=jobclass, y=wage, hue=race)
# > 🎯 **ADsP 개념**: 다변량(2범주×연속형) 분포 비교

# %%
my_plot.violinplot(origin, x='jobclass', y='wage' , hue='race', title='직군에 따른 인종별 임금분포')

# %% [markdown]
# ## 문제 10. 나이(`age`)가 많아질수록 임금(`wage`)은 대체로 어떻게 변하는가?
#
# ① 계속 가파르게 증가한다  ② 중년까지 증가하다 이후 정체·감소하는 경향  ③ 계속 감소한다  ④ 아무런 경향이 없다
#
# > 💡 **힌트**: 산점도 + 추세선(lmplot)
# > 🎯 **ADsP 개념**: 산점도·추세선 해석 · 비선형 추세

# %%
my_plot.lmplot(data=origin, x='age', y='wage', title='나이에 따른 임금변화', scatter_edgecolor='#000000', scatter_linewidths=1, linecolor='#00ff00', linestyle='--', linewidth=1)

# %% [markdown]
# ## 정답
# #### 나이가 증가할수록 연봉도 올라가는 추세선이 보인다.

# %% [markdown]
# ## 문제 11. 연령대별 평균 임금이 가장 높은 구간은?
#
# ① 20대 이하  ② 30대  ③ 40대  ④ 60대 이상
#
# > 💡 **힌트**: 산점도(lmplot) 또는 연령대 구간화 후 막대그래프
# > 🎯 **ADsP 개념**: 연속형 변수의 구간화(binning) · 비선형 추세

# %%
df['age'] =

# %% [markdown]
# ## 문제 12. 연도(`year`)별 임금 추이를 교육 수준(`education`)별로 나누어 볼 때, 임금이 가장 높고 변동(상승 후 2009년 하락)이 가장 두드러진 집단은?
#
# ① < HS Grad  ② HS Grad  ③ College Grad  ④ Advanced Degree
#
# > 💡 **힌트**: 선그래프(lineplot, x=year, y=wage, hue=education)
# > 🎯 **ADsP 개념**: 시계열 추세 · 집단별 추이 비교

# %% [markdown]
# ## 문제 13. 직군(`jobclass`)별 건강상태(`health`)를 비교할 때, 평균 이하(≤Good) 건강상태 비중이 더 높은 직군은?
#
# ① 생산직(Industrial)  ② 사무직(Information)  ③ 동일하다  ④ 사무직에만 나타난다
#
# > 💡 **힌트**: 막대그래프(countplot, x=jobclass, hue=health) 또는 누적막대그래프
# > 🎯 **ADsP 개념**: 교차분석(분할표) · 범주×범주 관계

# %% [markdown]
# ## 문제 14. 고임금자(`wage` 250 초과)는 어느 직군에 더 많이 분포하는가?
#
# ① 생산직(Industrial)  ② 사무직(Information)  ③ 동일하다  ④ 생산직에만 있다
#
# > 💡 **힌트**: 막대그래프(countplot, wage>250 필터 후 jobclass) 또는 누적막대그래프
# > 🎯 **ADsP 개념**: 조건부 필터링 · 교차 빈도 분석

# %% [markdown]
# ## 문제 15. 나이(`age`)와 임금(`wage`)을 각각 박스플롯으로 그렸을 때, 데이터가 더 넓은 범위에 퍼져(산포가 큰) 있는 변수는?
#
# ① age  ② wage  ③ 두 변수의 퍼짐이 동일하다  ④ 판단할 수 없다
#
# > 💡 **힌트**: 박스플롯 (두 변수를 개별적으로)
# > 🎯 **ADsP 개념**: 산포(범위 · 사분위 범위(IQR) · 표준편차)
