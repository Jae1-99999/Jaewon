# %% [markdown]
# # [LAB-06] 7. Heat Map
#
# ## #01. 준비작업
#
# ### 1. 패키치 참조

# %%
from jussam import load_data
from helper import *
from pandas import pivot_table
import seaborn as sb

# 다른 plot에서는 palette를 쓰는데 히트맵에서는 cmap을 쓴다.
# Out:
# 📦 연세대학교 주영아 교수가 제작한 라이브러리를 사용중입니다.
# 📧 Email(1): j.purplerose@yonsei.ac.kr
# 📧 Email(2): j.purplerose@gmail.com
# 📝 Website: https://juyounga.kr/

# %% [markdown]
# ### 2. 데이터 가져오기

# %%
origin = load_data('flights')
origin
# Out:
# 📚 어느 항공사의 년/월별 국제선 탑승객 수(출처: seaborn 내장 데이터)
#      year      month  passengers
# 0    1949    January         112
# 1    1949   February         118
# 2    1949      March         132
# 3    1949      April         129
# 4    1949        May         121
# ..    ...        ...         ...
# 139  1960     August         606
# 140  1960  September         508
# 141  1960    October         461
# 142  1960   November         390
# 143  1960   December         432
#
# [144 rows x 3 columns]

# %% [markdown]
# ### 3. 데이터 전처리 (1)
#
# - 영문 월 이름을 숫자로 변환

# %%
df = origin.copy()
df['month'] = df['month'].map({
    "January": 1, "February": 2, "March": 3, "April": 4,
    "May": 5, "June": 6, "July": 7, "August": 8, "September": 9, "October": 10,
    "November": 11, "December": 12
})

df.head()
# Out:
#    year  month  passengers
# 0  1949      1         112
# 1  1949      2         118
# 2  1949      3         132
# 3  1949      4         129
# 4  1949      5         121

# %% [markdown]
# ### 4. 데이터 전처리 (2)
#
# - 히트맵에 적합한 형태로 데이터 재구조화
#   - 히트맵은 피벗 테이블 형태의 테이블을 시각화 한다.

# %%
df2 = pivot_table(df, index="year", columns="month", values="passengers")
df2
# Out:
# month      1       2       3       4       5       6       7       8       9   \
# year
# 1949  112.000 118.000 132.000 129.000 121.000 135.000 148.000 148.000 136.000
# 1950  115.000 126.000 141.000 135.000 125.000 149.000 170.000 170.000 158.000
# 1951  145.000 150.000 178.000 163.000 172.000 178.000 199.000 199.000 184.000
# 1952  171.000 180.000 193.000 181.000 183.000 218.000 230.000 242.000 209.000
# 1953  196.000 196.000 236.000 235.000 229.000 243.000 264.000 272.000 237.000
# 1954  204.000 188.000 235.000 227.000 234.000 264.000 302.000 293.000 259.000
# 1955  242.000 233.000 267.000 269.000 270.000 315.000 364.000 347.000 312.000
# 1956  284.000 277.000 317.000 313.000 318.000 374.000 413.000 405.000 355.000
# 1957  315.000 301.000 356.000 348.000 355.000 422.000 465.000 467.000 404.000
# 1958  340.000 318.000 362.000 348.000 363.000 435.000 491.000 505.000 404.000
# 1959  360.000 342.000 406.000 396.000 420.000 472.000 548.000 559.000 463.000
# ...

# %% [markdown]
# ### 5. 데이터 전처리 (3)
#
# - 년도 역순으로 정렬

# %%
df3 = df2.sort_index(ascending=False)
df3
# Out:
# month      1       2       3       4       5       6       7       8       9   \
# year
# 1960  417.000 391.000 419.000 461.000 472.000 535.000 622.000 606.000 508.000
# 1959  360.000 342.000 406.000 396.000 420.000 472.000 548.000 559.000 463.000
# 1958  340.000 318.000 362.000 348.000 363.000 435.000 491.000 505.000 404.000
# 1957  315.000 301.000 356.000 348.000 355.000 422.000 465.000 467.000 404.000
# 1956  284.000 277.000 317.000 313.000 318.000 374.000 413.000 405.000 355.000
# 1955  242.000 233.000 267.000 269.000 270.000 315.000 364.000 347.000 312.000
# 1954  204.000 188.000 235.000 227.000 234.000 264.000 302.000 293.000 259.000
# 1953  196.000 196.000 236.000 235.000 229.000 243.000 264.000 272.000 237.000
# 1952  171.000 180.000 193.000 181.000 183.000 218.000 230.000 242.000 209.000
# 1951  145.000 150.000 178.000 163.000 172.000 178.000 199.000 199.000 184.000
# 1950  115.000 126.000 141.000 135.000 125.000 149.000 170.000 170.000 158.000
# ...

# %% [markdown]
# ## #02. Heatmap 시각화
#
# ### 1. 년도/월별 탑승객 수 분포 시각화

# %%
fig, ax = my_plot.init(width=1200, height=600,
                       title="Heatmap of Passengers by Year and Month", xlabel="month", ylabel="year")

  # 격자 제거
ax.grid(False)
# 2) heatmap 그리기
# -> annot=True : 수치값을 함께 표시함
# -> fmt: annot=True가 설정된 경우 표시되는 수치값의 형식 지정
# -> linewidth: 각 셀 사이의 선 굵기
# -> cmap: 칼라맵 ('Greys' 등)

sb.heatmap(data=df3, annot=True, fmt="0.1f", linewidths=0.5, cmap="GnBu")

my_plot.show()

# %% [markdown]
# #### 💡 인사이트
#
# - 📈 연도 증가에 따라 전반적 승객 수가 뚜렷하게 증가함.
#   - 예) 1949년 7월 148 → 1960년 7월 622
# - 🌞 계절 패턴이 반복적으로 나타남: 매년 7~8월이 고점, 11~2월이 저점 구간임.
# - 🔝 전체 최댓값은 1960년 7월 622로 확인됨.
# - 🔻 전체 최솟값은 1949년 11월 104로 확인됨.
# - 📊 같은 월 기준으로도 연도별 상승 흐름이 일관됨.
#   - 예: 1월 112→417, 12월 118→432
# - 🌡️ 고연도로 갈수록 고점과 저점의 차이가 커져, 계절 변동 폭도 함께 확대되는 모습이 보임.

# %% [markdown]
# ## #03. 모듈화 기능 확인
#
# ### 1. 년도/월별 탑승객 수 분포 시각화

# %%
my_plot.heatmap(df3, palette="PuRd", width=1200, height=600,
                title="Hearmap of Passengers by Year and Month",
                xlabel="month", ylabel="year")

# %% [markdown]
# #### 연습문제. 교통사고 현황 데이터의 인사이트 찾기
# ##### traffic_acc 데이터 셋은 2005년 1월부터 2018년 12월 까지 월별 교통사고의 발생건수, 부상자수, 사망자수 데이터이다
# ##### 이 데이터셋을 활용하여 년도에 따른 월별 교통사고 발생건수를 히트맵으로 시각화 하고 다음의 물음에 답하시오.

# %%
# 0. 필요한 모듈 불러오기
from jussam import load_data
from helper import *
from pandas import pivot_table
import seaborn as sb

# %%
# 1. 데이터셋 불러오기
acc = load_data('traffic_acc')
acc.info()
acc.head()
# Out:
# 📚 2005년 1월 부터 2018년 12월 까지 월별 교통사고의 발생건수,부상자수,사망자수 데이터(인덱스/메타데이터 없음, 출처: 공공데이터포털)
# <class 'pandas.DataFrame'>
# RangeIndex: 168 entries, 0 to 167
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   년도      168 non-null    int64
#  1   월       168 non-null    int64
#  2   발생건수    168 non-null    int64
#  3   사망자수    168 non-null    int64
#  4   부상자수    168 non-null    int64
# dtypes: int64(5)
# memory usage: 6.7 KB
#      년도  월   발생건수  사망자수   부상자수
# 0  2005  1  15494   504  25413
# 1  2005  2  13244   431  21635
# 2  2005  3  16580   477  25550
# 3  2005  4  17817   507  28131
# 4  2005  5  19085   571  29808

# %%
# 2. 컬럼 및 인덱스 피벗테이블화
accdf = acc.pivot_table(index="년도", columns="월", values="발생건수")
accdf
# Out:
# 월           1         2         3         4         5         6         7   \
# 년도
# 2005 15494.000 13244.000 16580.000 17817.000 19085.000 18092.000 18675.000
# 2006 14971.000 14270.000 16767.000 17948.000 19140.000 17435.000 18634.000
# 2007 14914.000 14696.000 18166.000 18055.000 19264.000 18310.000 18037.000
# 2008 14741.000 14176.000 16752.000 17498.000 19515.000 18824.000 19562.000
# 2009 16532.000 15502.000 18224.000 19153.000 20237.000 19249.000 20281.000
# 2010 17124.000 15803.000 17801.000 18386.000 20372.000 18910.000 18965.000
# 2011 16454.000 14208.000 16832.000 18570.000 19414.000 18505.000 19253.000
# 2012 16818.000 16656.000 18255.000 19372.000 19672.000 18854.000 19333.000
# 2013 16016.000 14187.000 17465.000 18031.000 19686.000 18329.000 18441.000
# 2014 15905.000 14061.000 18420.000 18443.000 20314.000 18530.000 19649.000
# 2015 16902.000 14939.000 18616.000 19386.000 20543.000 18649.000 20278.000
# ...

# %%
# 3. 년도 최신부터
accdf2 = accdf.sort_index(ascending=False)
accdf2
# Out:
# 월           1         2         3         4         5         6         7   \
# 년도
# 2018 17026.000 16208.000 17022.000 17992.000 18636.000 18082.000 18699.000
# 2017 16970.000 14832.000 17047.000 17717.000 18502.000 18047.000 18158.000
# 2016 17067.000 15664.000 17946.000 19452.000 19554.000 17977.000 18955.000
# 2015 16902.000 14939.000 18616.000 19386.000 20543.000 18649.000 20278.000
# 2014 15905.000 14061.000 18420.000 18443.000 20314.000 18530.000 19649.000
# 2013 16016.000 14187.000 17465.000 18031.000 19686.000 18329.000 18441.000
# 2012 16818.000 16656.000 18255.000 19372.000 19672.000 18854.000 19333.000
# 2011 16454.000 14208.000 16832.000 18570.000 19414.000 18505.000 19253.000
# 2010 17124.000 15803.000 17801.000 18386.000 20372.000 18910.000 18965.000
# 2009 16532.000 15502.000 18224.000 19153.000 20237.000 19249.000 20281.000
# 2008 14741.000 14176.000 16752.000 17498.000 19515.000 18824.000 19562.000
# ...

# %%
# 4. 히트맵 시각화
my_plot.heatmap(data=accdf2, xlabel="month", ylabel="year", title="년도에 따른 월별 교통사고 발생건수", palette="PuRd", fmt="0.1f")

# %% [markdown]
# #### 문 제 1. 히트맵에서 매년 공통적으로 색이 가장 옅게(밝게) 나타나, 사고 발생건수가 가장 적은 월은?
# ###### 매년 2월에 사고가 적게 나타는걸 알수가 있고 2005년 02월에 사고건수가 제일 적다.
# #### 문 제 2. 히트맵 전체 기간(2005년~2018년) 중에서 색이 가장 진하게 나타나 최대 발생건수를 기록한 년-월은?
# ###### 2015년 10월에 21587건으로 제일 많이 나타남
# #### 문 제 3. 히트맵을 월(가로축) 기준으로 비교했을때 색이 가장 진하게 나타나, 평균적으로 사고 발생건수가 가장 많은 달은?
# ###### 히트맵을 보면 매년 10월에 가장 색이 진하게 나타나는 걸 보인다.
